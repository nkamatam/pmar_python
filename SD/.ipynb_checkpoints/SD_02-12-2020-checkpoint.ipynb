# %%
"10" + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-1065449e45f5> in <module>
# ----> 1 "10" + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("*")
print("**")
print("***")
# Out:
# *
# **
# ***

# %%
for i in range (1,7+1):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******

# %%
for i in range (10,0,-1):
    print("*"*(i))

# %%
for i in range (10,0,-1):
    print("*"*(i-1))
# Out:
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
for i in range (10,0):
    print("*"*(i-1))

# %%
for i in range (1,7+1):
    print(" ""*"*(7+i))
# Out:
#  * * * * * * * *
#  * * * * * * * * *
#  * * * * * * * * * *
#  * * * * * * * * * * *
#  * * * * * * * * * * * *
#  * * * * * * * * * * * * *
#  * * * * * * * * * * * * * *

# %%
for i in range (0,8,1):
    print(" "*(8-i)+"*"*(2*i+1))
# Out:
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************

# %%
for i in range (0,8,1):
    print(" "*(8-i)+"*"*(2*i+1))
for i in range (8,0,-1):
    print(" "*(9-i)+"*"*(2*i-1))
# Out:
#         *
#        ***
#       *****
#      *******
#     *********
#    ***********
#   *************
#  ***************
#  ***************
#   *************
#    ***********
#     *********
#      *******
#       *****
#        ***
#         *
