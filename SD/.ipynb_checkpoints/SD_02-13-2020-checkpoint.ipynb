# %%
for i in range (1,10):
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
import math

# %%
math.log(1)
# Out:
# 0.0

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.log(math.e)
# Out:
# 1.0

# %%
N=0
for i in range (0,10+1):
    N=(i+N)
print(N)
# Out:
# 55

# %%
N=0
for i in range (1,10+1,2):
    N=(i+N)
print(N)
# Out:
# 25

# %%
N=0
for i in range (1,10+1):
    N=(i*i+N)
print(N)
# Out:
# 385

# %%
N=0
for i in range (1,):
        N=(i*i+N)
        if (i<=100):
            print(N)
# Out:
# 0

# %%
N=1
for i in range (1,10+1):
    N=(i * N)
print(N)
# Out:
# 3628800

# %%
first=0
second=1
fib=0
while(first+second<10):
    fib=first+second
    print(fib)
    first=second
    second=fib
# Out:
# 1
# 2
# 3
# 5
# 8

# %%
first=0
second=1
fib=0
print(first)
print(second)
while(fib<10):
    fib=first+second
    print(fib)
    first=second
    second=fib
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
