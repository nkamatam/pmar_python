# %% [markdown]
# # [Numbers](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex)

# %% [markdown]
# ## `int`

# %%
my_int = 6

print('value: {}, type: {}'.format(my_int, type(my_int)))
# Out:
# value: 6, type: <class 'int'>

# %% [markdown]
# ## `float`

# %%
my_float = float(my_int)
print('value: {}, type: {}'.format(my_float, type(my_float)))
# Out:
# value: 6.0, type: <class 'float'>

# %% [markdown]
# Note that division of `int`s produces `float`:

# %%
print(1 / 1)
print(6 / 5)
# Out:
# 1.0
# 1.2

# %% [markdown]
# Be aware of the binary floating-point pitfalls (see [Decimal](#decimal) for workaround):

# %%
import math
val = 0.1 + 0.1 + 0.1+math.pi
print(val == 0.3)
print("3%.5"%val)
# Out:
# False
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b762c9dcb613> in <module>
#       2 val = 0.1 + 0.1 + 0.1+math.pi
#       3 print(val == 0.3)
# ----> 4 print("3%.5"%val)
#
# ValueError: incomplete format

# %%
val = 0.1 + 0.1 + 0.1
print(val == 0.3)
print(val)
# Out:
# False
# 0.30000000000000004

# %% [markdown]
# ## Floor division `//`, modulus `%`, power `**`

# %%
7 // 5
# Out:
# 1

# %%
7 % 5
# Out:
# 2

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# <a id='decimal'></a>
# ## [`decimal.Decimal`](https://docs.python.org/3/library/decimal.html)

# %%
from decimal import Decimal

# %%
from_float = Decimal(0.1)
from_str = Decimal('0.1')
print('from float: {}\nfrom string type: {}\nfrom string: {}'.format(from_float, type(from_str),from_str))
# Out:
# from float: 0.1000000000000000055511151231257827021181583404541015625
# from string type: <class 'decimal.Decimal'>
# from string: 0.1

# %%
my_decimal = Decimal('0.1')
sum_of_decimals = my_decimal + my_decimal + my_decimal
print(sum_of_decimals == Decimal('0.3'))
# Out:
# True

# %% [markdown]
# ## Operator precedence in calculations
# Mathematical operator precedence applies. Use brackets if you want to change the execution order:

# %%
print(1 + 2**2 * 3 / 6) # 1 + 4 * 3 / 6 == 1 + 12 / 6 == 1 + 2
print((1 + 2**2) * 3 / 6)
# Out:
# 3.0
# 2.5

# %%
import math
